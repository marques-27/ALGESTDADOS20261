# %% [markdown]
# <a href="https://colab.research.google.com/github/marques-27/ALGORITMO-ADRIANA-20261/blob/main/AULA1%20TESTE-SEMANA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("strogonoff_de_frango ")
# Out:
# strogonoff_de_frango

# %%
print("mediucre_aquele_que_ofende_o_colega_para_se_mostrar_superior")
# Out:
# mediucre_aquele_que_ofende_o_colega_para_se_mostrar_superior
